# %%
import pandas as pd 
import numpy as np  
import matplotlib.pyplot as plt 
# %matplotlib inline 
import seaborn as sns
import datetime
from datetime import date, timedelta

from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier
from sklearn.externals import joblib
from scipy.stats import norm
from sklearn.model_selection import train_test_split
from pandas.plotting import scatter_matrix

import pylab as pl
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

import pickle

from sklearn.tree import DecisionTreeClassifier

from sklearn.tree import export_graphviz 
    #In the cmd line type: conda install python-graphviz
import graphviz
import os
os.environ["PATH"] += os.pathsep + 'D:/Program Files (x86)/Graphviz2.38/bin/'

from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import roc_curve
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv("no_show_original_data_2016_with_update_weather.csv") 
df=df.drop(['Unnamed: 0'], axis=1)

# %%
#ScheduledDay קיצוץ התאריך של והופך את התאריך לסוג דייטיים
df['ScheduledDay'] =df['ScheduledDay'].apply(str)
df['ScheduledDay'] = df['ScheduledDay'].str.slice(0, 10, 1) 
df['ScheduledDay'] =  pd.to_datetime(df['ScheduledDay'], format='%Y-%m-%d')
# Out:
# 0       2016-04-29
# 52751   2016-04-29
# 52750   2016-04-29
# 52749   2016-04-29
# 52748   2016-04-29
# Name: AppointmentDay, dtype: datetime64[ns]

# %%
# הפיכת שדות מז"א למספריים
df['prcp']=df['prcp'].astype(float).astype(int)
df['temp']=df['temp'].astype(float).astype(int)

# %%
#AppointmentDay הופך את התאריך לסוג דייטיים
df['AppointmentDay'] =df['AppointmentDay'].apply(str)
df['AppointmentDay'] = df['AppointmentDay'].str.slice(0, 10, 1) 
df['AppointmentDay'] =  pd.to_datetime(df['AppointmentDay'], format='%Y-%m-%d')

# %%
# הכנסת קודים לשכונות
df.loc[:, 'Neighbourhood_codes'] = df["Neighbourhood"].astype("category").cat.codes+1
# הפיכת שדות קטגוריים לבינריים
df.loc[:, 'Gender_'] = df["Gender"].astype("category").cat.codes
#Woman=0, Man=1
df.loc[:, 'No-show_'] = df["No-show"].astype("category").cat.codes
#show=0, no-show=1

# %%
#הוספת שדה של יום בשבוע של הבדיקה
dayOfWeek={0:'Monday', 1:'Tuesday', 2:'Wednesday', 3:'Thursday', 4:'Friday', 5:'Saturday', 6:'Sunday'}
df['Appointment_Week_Day'] = df['AppointmentDay'].dt.dayofweek.map(dayOfWeek)

# %%
#הוספת שדה של המרווח בין הבדיקות
df['Delta_Dates'] = (df['AppointmentDay']-df['ScheduledDay']).dt.days
# בדיקות שתואמו אחרי הבדיקה עצמה יופיעו כמינוס 1-כי לא הגיוני
mask = df.Delta_Dates < 0
column_name = 'Delta_Dates'
df.loc[mask, column_name] = -1

# %%
# חיתוך כל מי שיש לו דלתא קטנה מ1
#df[df.Delta_Dates < 1] מוחק
#38562 רשומות של פגישות שנקבעו באותו תאריך
# 5 רשומות של דלתא שלילית=לא הגיוני
df = df.drop(df[df.Delta_Dates < 1].index)

# %%
#Get Dummies לימי השבוע של הפגישה
week_day=pd.get_dummies(df["Appointment_Week_Day"])
week_day["AppointmentID"] = df["AppointmentID"]
df=df.merge(week_day, how='left', on='AppointmentID')
df = df.drop(['Appointment_Week_Day'], axis=1)

# %%
# מוסיף עמודה של כמות פגישות לכל מטופל
a=df.groupby(['PatientId']).size().reset_index(name='Appointment_counts')
df=df.merge(a, how='left', on='PatientId')
#בדיקה עצמית לקוד
#df.loc[df['PatientId'] == 1.885170e+14]

# %%
#Get Dummies לשכונות
NC=pd.get_dummies(df["Neighbourhood_codes"])
NC["AppointmentID"] = df["AppointmentID"]
df=df.merge(NC, how='left', on='AppointmentID')

# %%
df["yesterday"] = df["AppointmentDay"] - timedelta(1)

# %%
df = df.sort_values(by='AppointmentDay')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 71959 entries, 0 to 48112
# Columns: 110 entries, PatientId to meetings_per_day
# dtypes: datetime64[ns](3), float64(2), int32(2), int64(11), int8(3), object(3), uint8(86)
# memory usage: 17.6+ MB

# %%
mpd = df["AppointmentDay"].value_counts().sort_index()
mpd.index[22]
# Out:
# Timestamp('2016-06-02 00:00:00')

# %%
df["yesterday_no_show_percentage"] = '0'

for i, row in df.iterrows():
    yesterday_date=df.iloc[i]["yesterday"]
    #חיתוך לדאטהפריים של אתמול בלבד
    df_yesterday=df[df["AppointmentDay"] == yesterday_date] 
    countt=df_yesterday['No-show_'].count()
    summ= df_yesterday['No-show_'].sum()
    if count>0: 
        df.set_value(i,"yesterday_no_show_percentage",summ/countt, takeable=False)
# Out:
# C:\Users\lapid\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in longlong_scalars
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\lapid\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.

# %%
conditions = [(df['AppointmentDay'] == mpd.index[0]),
             (df['AppointmentDay'] == mpd.index[1]),
             (df['AppointmentDay'] == mpd.index[2]),
             (df['AppointmentDay'] == mpd.index[3]),
             (df['AppointmentDay'] == mpd.index[4]),
             (df['AppointmentDay'] == mpd.index[5]),
             (df['AppointmentDay'] == mpd.index[6]),
             (df['AppointmentDay'] == mpd.index[7]),
             (df['AppointmentDay'] == mpd.index[8]),
             (df['AppointmentDay'] == mpd.index[9]),
             (df['AppointmentDay'] == mpd.index[10]),
             (df['AppointmentDay'] == mpd.index[11]),
             (df['AppointmentDay'] == mpd.index[12]),
             (df['AppointmentDay'] == mpd.index[13]),
             (df['AppointmentDay'] == mpd.index[14]),
             (df['AppointmentDay'] == mpd.index[15]),
             (df['AppointmentDay'] == mpd.index[16]),
             (df['AppointmentDay'] == mpd.index[17]),
             (df['AppointmentDay'] == mpd.index[18]),
             (df['AppointmentDay'] == mpd.index[19]),
             (df['AppointmentDay'] == mpd.index[20]),
             (df['AppointmentDay'] == mpd.index[21]),
             (df['AppointmentDay'] == mpd.index[22]),
             (df['AppointmentDay'] == mpd.index[23]),
             (df['AppointmentDay'] == mpd.index[24]),
             (df['AppointmentDay'] == mpd.index[25]),
             (df['AppointmentDay'] == mpd.index[26])]
choices = [mpd[0], mpd[1],mpd[2],mpd[3],mpd[4],mpd[5],mpd[6],mpd[7],mpd[8],mpd[9],mpd[10],mpd[11],mpd[12],mpd[13],
          mpd[14], mpd[15],mpd[16],mpd[17],mpd[18],mpd[19],mpd[20],mpd[21],mpd[22],mpd[23],mpd[24],mpd[25],mpd[26]]
df['meetings_per_day'] = np.select(conditions, choices, default='0')

# %%
choices = []

# %%
df
# Out:
#           PatientId  AppointmentID Gender ScheduledDay AppointmentDay  Age  \
# 0      2.366230e+14        5628286      M   2016-04-27     2016-04-29    0
# 17053  1.284760e+14        5631071      M   2016-04-27     2016-04-29   19
# 17055  6.971810e+13        5623000      F   2016-04-26     2016-04-29   19
# 62467              ...                0   0   0  0   0   0   0 2016-06-07
# 32731              ...                0   0   0  0   0   0   0 2016-06-07
# 9851               ...                0   0   0  0   0   0   0 2016-06-07
# 9852               ...                0   0   0  0   0   0   0 2016-06-07
# 7313               ...                0   0   0  0   0   0   0 2016-06-07
# 9855               ...                0   0   0  0   0   0   0 2016-06-07
# 42166              ...                0   0   1  0   0   0   0 2016-06-07
# 32724              ...                0   0   0  0   0   0   0 2016-06-07
# 9856               ...                0   0   0  0   0   0   0 2016-06-07
# 32721              ...                0   0   0  0   0   0   0 2016-06-07
# 7312               ...                0   0   0  0   0   0   0 2016-06-07
# 42135              ...                0   0   0  0   0   0   0 2016-06-07
# 32697              ...                0   0   0  0   0   0   0 2016-06-07
# 62457              ...                0   0   0  0   0   0   0 2016-06-07
# 42191              ...                0   0   0  0   1   0   0 2016-06-07
# 48112              ...                0   0   0  0   0   0   0 2016-06-07
#
#        meetings_per_day  yesterday_no_show_percentage
# 0                  2182                           NaN
# 17053              2182                           NaN
# 17055              2182                           NaN
# 28936              2182                      0.270063
# 52751              2182                      0.294015
# 52750              2182                      0.294015
# 52749              2182                      0.294015
# 52748              2182                      0.294015
# 52747              2182                      0.294015
# 52746              2182                      0.294015
# 52745              2182                      0.294015
# 52744              2182                      0.294015
# 52743              2182                      0.294015
# 52742              2182                      0.294015
# 52741              2182                      0.294015
# 52740              2182                      0.294015
# 52739              2182                      0.294015
# 52738              2182                      0.294015
# 52737              2182                      0.294015
# 52736              2182                      0.294015
# 52735              2182                      0.294015
# 52734              2182                      0.294015
# 52733              2182                      0.294015
# 52732              2182                      0.294015
# 52731              2182                      0.294015
# 9184               2182                      0.277427
# 9185               2182                      0.277427
# 9186               2182                      0.277427
# 9187               2182                      0.277427
# 9188               2182                      0.277427
# ...                 ...                           ...
# 3861               2942                           NaN
# 42170              2942                      0.285118
# 7327               2942                      0.290172
# 9864               2942                      0.277427
# 41170              2942                      0.283951
# 32678              2942                           NaN
# 56989              2942                      0.243894
# 62454              2942                      0.264416
# 42113              2942                      0.285118
# 42146              2942                      0.285118
# 42147              2942                      0.285118
# 7319               2942                      0.290172
# 42160              2942                      0.285118
# 7318               2942                      0.290172
# 62467              2942                      0.264416
# 32731              2942                           NaN
# 9851               2942                      0.277427
# 9852               2942                      0.277427
# 7313               2942                      0.290172
# 9855               2942                      0.277427
# 42166              2942                      0.285118
# 32724              2942                           NaN
# 9856               2942                      0.277427
# 32721              2942                           NaN
# 7312               2942                      0.290172
# 42135              2942                      0.285118
# 32697              2942                           NaN
# 62457              2942                      0.264416
# 42191              2942                      0.285118
# 48112              2942                      0.310429
#
# [71959 rows x 111 columns]

# %%
for i in range(0,26):
    if df["AppointmentDay"][i] in amd.index[i]:
        print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-236-e2a3bf154b2e> in <module>()
#       1 for i in range(0,26):
# ----> 2     if df["AppointmentDay"][i] in amd.index[i]:
#       3         print(i)
#
# TypeError: argument of type 'Timestamp' is not iterable

# %% [markdown]
# לסכום לכל שורה את סך הפגישות של אתמול

# %%
u_days= df["AppointmentDay"].unique()
u_days
# Out:
# array(['2016-04-29T00:00:00.000000000', '2016-05-02T00:00:00.000000000',
#        '2016-05-03T00:00:00.000000000', '2016-05-04T00:00:00.000000000',
#        '2016-05-05T00:00:00.000000000', '2016-05-06T00:00:00.000000000',
#        '2016-05-09T00:00:00.000000000', '2016-05-10T00:00:00.000000000',
#        '2016-05-11T00:00:00.000000000', '2016-05-12T00:00:00.000000000',
#        '2016-05-13T00:00:00.000000000', '2016-05-14T00:00:00.000000000',
#        '2016-05-16T00:00:00.000000000', '2016-05-17T00:00:00.000000000',
#        '2016-05-18T00:00:00.000000000', '2016-05-19T00:00:00.000000000',
#        '2016-05-20T00:00:00.000000000', '2016-05-24T00:00:00.000000000',
#        '2016-05-25T00:00:00.000000000', '2016-05-30T00:00:00.000000000',
#        '2016-05-31T00:00:00.000000000', '2016-06-01T00:00:00.000000000',
#        '2016-06-02T00:00:00.000000000', '2016-06-03T00:00:00.000000000',
#        '2016-06-06T00:00:00.000000000', '2016-06-07T00:00:00.000000000',
#        '2016-06-08T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
df["AppointmentDay"][3122]
# Out:
# Timestamp('2016-06-08 00:00:00')

# %%
for i in df["AppointmentDay"]:
    if df["AppointmentDay"][i] in meetings["AppointmentDay"]:
        print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-187-b93690bb7551> in <module>()
#       1 for i in df["AppointmentDay"]:
# ----> 2     if df["AppointmentDay"][i] in meetings["AppointmentDay"]:
#       3         print(i)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     764         key = com._apply_if_callable(key, self)
#     765         try:
# --> 766             result = self.index.get_value(self, key)
#     767
#     768             if not is_scalar(result):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    3101         try:
#    3102             return self._engine.get_value(s, k,
# -> 3103                                           tz=getattr(series.dtype, 'tz', None))
#    3104         except KeyError as e1:
#    3105             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# KeyError: Timestamp('2016-04-29 00:00:00')

# %%
meetings["Appointment_day"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# KeyError: 'Appointment_day'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-246-7cfacaa3df4b> in <module>()
# ----> 1 meetings["Appointment_day"]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2484         res = cache.get(item)
#    2485         if res is None:
# -> 2486             values = self._data.get(item)
#    2487             res = self._box_item_values(item, values)
#    2488             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
# -> 3065                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3066
#    3067         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# KeyError: 'Appointment_day'

# %%
df['meeting_per_day'] = np.select(conditions, choices, default='black')

# %%
df
# Out:
#           PatientId  AppointmentID Gender ScheduledDay AppointmentDay  Age  \
# 0      2.366230e+14        5628286      M   2016-04-27     2016-04-29    0
# 52751  7.544920e+13        5625104      F   2016-04-27     2016-04-29   56
# 52750  1.484140e+12        5573128      F   2016-04-12     2016-04-29   56
# 52749  9.977160e+14        5451635      F   2016-03-10     2016-04-29   56
# 52748  7.537280e+13        5636838      F   2016-04-28     2016-04-29   56
# 52747  2.349970e+11        5413185      F   2016-03-01     2016-04-29   56
# 52746  4.727620e+13        5601894      M   2016-04-19     2016-04-29   56
# 52745  7.116340e+14        5502125      F   2016-03-22     2016-04-29   56
# 52744  8.361420e+13        5611825      F   2016-04-25     2016-04-29   56
# 52743  7.123990e+13        5631867      M   2016-04-28     2016-04-29   56
# 52742  1.482630e+13        5600587      F   2016-04-19     2016-04-29   56
# 52741  2.178300e+13        5531300      F   2016-03-31     2016-04-29   56
# 52740  6.787690e+11        5563183      M   2016-04-08     2016-04-29   56
# 52739  1.918230e+12        5625001      F   2016-04-26     2016-04-29   56
# 52738  2.667290e+12        5592387      M   2016-04-18     2016-04-29   56
# 52737  6.771830e+14        5629128      F   2016-04-27     2016-04-29   56
# 52731               NaN
# 9184                NaN
# 9185                NaN
# 9186                NaN
# 9187                NaN
# 9188                NaN
# 9189                NaN
# 52752               NaN
# 9190                NaN
# ...                 ...
# 42214               NaN
# 32713               NaN
# 32640               NaN
# 3861                NaN
# 42170               NaN
# 69426               NaN
# 7327                NaN
# 42134               NaN
# 42135               NaN
# 42140               NaN
# 42141               NaN
# 18794               NaN
# 42146               NaN
# 42147               NaN
# 7319                NaN
# 42160               NaN
# 7318                NaN
# 62467               NaN
# 32731               NaN
# 9851                NaN
# 9852                NaN
# 7313                NaN
# 9855                NaN
# 42166               NaN
# 32724               NaN
# 9856                NaN
# 32721               NaN
# 7312                NaN
# 42172               NaN
# 48112               NaN
#
# [71959 rows x 110 columns]

# %%
meetings = pd.DataFrame(df.groupby('AppointmentDay').count()[::1][1])
meetings
# Out:
#                    1
# AppointmentDay
# 2016-04-29      2182
# 2016-05-02      2788
# 2016-05-03      2689
# 2016-05-04      2811
# 2016-05-05      2739
# 2016-05-06      2513
# 2016-05-09      2849
# 2016-05-10      2731
# 2016-05-11      2952
# 2016-05-12      2866
# 2016-05-13      2608
# 2016-05-14        31
# 2016-05-16      2997
# 2016-05-17      2860
# 2016-05-18      2916
# 2016-05-19      2876
# 2016-05-20      2534
# 2016-05-24      2445
# 2016-05-25      2486
# 2016-05-30      2874
# 2016-05-31      2866
# 2016-06-01      2937
# 2016-06-02      2844
# 2016-06-03      2679
# 2016-06-06      3073
# 2016-06-07      2871
# 2016-06-08      2942

# %%
# הורדת שדות מיותרים
#df = df.drop(columns=['PatientId', 'AppointmentID', 'Gender', 'ScheduledDay', 'No-show', 'Neighbourhood', 'Neighbourhood_codes','AppointmentDay'], axis = 1)

# %% [markdown]
# new_index_order = ['Age','Gender_','Delta_Dates','SMS_received', 'Friday', 'Monday', 'Saturday', 'Thursday', 'Tuesday', 'Wednesday','Scholarship', 'Hipertension', 'Diabetes', 'Alcoholism',
#        'Handcap','No-show_']
# df = df.reindex(columns=new_index_order)

# %%
df.head()
# Out:
#       PatientId  AppointmentID Gender ScheduledDay AppointmentDay  Age  \
# 0  2.366230e+14        5628286      M   2016-04-27     2016-04-29    0
# 1  1.885170e+14        5616082      M   2016-04-25     2016-04-29    0
# 2  2.718820e+14        5628321      M   2016-04-27     2016-04-29    0
# 3  3.326990e+12        5632495      F   2016-04-28     2016-04-29    0
# 4  8.468590e+14        5560742      M   2016-04-08     2016-04-29    0
#
#        Neighbourhood  Scholarship  Hipertension  Diabetes    ...      73  74  \
# 0       SÃO BENEDITO            0             0         0    ...       0   0
# 1  ILHA DAS CAIEIRAS            0             0         0    ...       0   0
# 2          CONQUISTA            0             0         0    ...       0   0
# 3      SANTO ANTÔNIO            0             0         0    ...       0   0
# 4       PRAIA DO SUÁ            0             0         0    ...       0   0
#
#    75 76  77  78  79  80  81  yesterday
# 0   1  0   0   0   0   0   0 2016-04-28
# 1   0  0   0   0   0   0   0 2016-04-28
# 2   0  0   0   0   0   0   0 2016-04-28
# 3   0  0   0   0   0   0   0 2016-04-28
# 4   0  0   0   0   0   0   0 2016-04-28
#
# [5 rows x 109 columns]

# %%
pickle.dump(df, open("df_c.dat", "wb"))
